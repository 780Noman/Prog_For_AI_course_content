# %%
import pandas as pd
df1 = pd.read_csv('D:\\5th sem doc\\Programming For AI\\after mid\Task\\tips.csv')
df2 = pd.read_csv('D:\\5th sem doc\\Programming For AI\\after mid\Task\\iris.csv')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df2['size'] = df2['sepal_length'] + df2['sepal_width'] + df2['petal_length'] + df2['petal_width']
df2['size'] = df2['size'].astype('int')
df2['size'] = df2['size'].replace([14, 15, 16], 3)
df2['size'] = df2['size'].replace([10, 11, 12,17], 1)
df2['size'] = df2['size'].replace([13,9], 2)
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  size
# 0             5.1          3.5           1.4          0.2     setosa     1
# 1             4.9          3.0           1.4          0.2     setosa     2
# 2             4.7          3.2           1.3          0.2     setosa     2
# 3             4.6          3.1           1.5          0.2     setosa     2
# 4             5.0          3.6           1.4          0.2     setosa     1
# ..            ...          ...           ...          ...        ...   ...
# 145           6.7          3.0           5.2          2.3  virginica     1
# 146           6.3          2.5           5.0          1.9  virginica     3
# 147           6.5          3.0           5.2          2.0  virginica     3
# 148           6.2          3.4           5.4          2.3  virginica     1
# 149           5.9          3.0           5.1          1.8  virginica     3
#
# [150 rows x 6 columns]

# %%
df3 = pd.merge(df1, df2, how='outer', on='size')

df3
# Out:
#       total_bill   tip     sex smoker  day    time  size  sepal_length  \
# 0          16.99  1.01  Female     No  Sun  Dinner     2           4.9
# 1          16.99  1.01  Female     No  Sun  Dinner     2           4.7
# 2          16.99  1.01  Female     No  Sun  Dinner     2           4.6
# 3          16.99  1.01  Female     No  Sun  Dinner     2           4.6
# 4          16.99  1.01  Female     No  Sun  Dinner     2           4.9
# ...          ...   ...     ...    ...  ...     ...   ...           ...
# 6946         NaN   NaN     NaN    NaN  NaN     NaN    19           7.7
# 6947         NaN   NaN     NaN    NaN  NaN     NaN    19           7.7
# 6948         NaN   NaN     NaN    NaN  NaN     NaN    19           7.7
# 6949         NaN   NaN     NaN    NaN  NaN     NaN    20           7.7
# 6950         NaN   NaN     NaN    NaN  NaN     NaN    20           7.9
#
#       sepal_width  petal_length  petal_width    species
# 0             3.0           1.4          0.2     setosa
# ...

# %%
df4 = pd.concat([df1, df2], axis=1)
df4
# Out:
#      total_bill   tip     sex smoker   day    time  size  sepal_length  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2           5.1
# 1         10.34  1.66    Male     No   Sun  Dinner     3           4.9
# 2         21.01  3.50    Male     No   Sun  Dinner     3           4.7
# 3         23.68  3.31    Male     No   Sun  Dinner     2           4.6
# 4         24.59  3.61  Female     No   Sun  Dinner     4           5.0
# ..          ...   ...     ...    ...   ...     ...   ...           ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3           NaN
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2           NaN
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2           NaN
# 242       17.82  1.75    Male     No   Sat  Dinner     2           NaN
# 243       18.78  3.00  Female     No  Thur  Dinner     2           NaN
#
#      sepal_width  petal_length  petal_width species  size
# ...

# %%
df3 = pd.merge(df1, df2, how='left', on='size')
df3
# Out:
#       total_bill   tip     sex smoker   day    time  size  sepal_length  \
# 0          16.99  1.01  Female     No   Sun  Dinner     2           4.9
# 1          16.99  1.01  Female     No   Sun  Dinner     2           4.7
# 2          16.99  1.01  Female     No   Sun  Dinner     2           4.6
# 3          16.99  1.01  Female     No   Sun  Dinner     2           4.6
# 4          16.99  1.01  Female     No   Sun  Dinner     2           4.9
# ...          ...   ...     ...    ...   ...     ...   ...           ...
# 6927       18.78  3.00  Female     No  Thur  Dinner     2           5.5
# 6928       18.78  3.00  Female     No  Thur  Dinner     2           5.8
# 6929       18.78  3.00  Female     No  Thur  Dinner     2           5.6
# 6930       18.78  3.00  Female     No  Thur  Dinner     2           5.7
# 6931       18.78  3.00  Female     No  Thur  Dinner     2           4.9
#
#       sepal_width  petal_length  petal_width     species
# ...

# %%
df3 = pd.merge(df1, df2, how='right', on='size')
df3
# Out:
#       total_bill   tip     sex smoker   day    time  size  sepal_length  \
# 0           3.07  1.00  Female    Yes   Sat  Dinner     1           5.1
# 1          10.07  1.83  Female     No  Thur   Lunch     1           5.1
# 2           7.25  1.00  Female     No   Sat  Dinner     1           5.1
# 3           8.58  1.92    Male    Yes   Fri   Lunch     1           5.1
# 4          16.99  1.01  Female     No   Sun  Dinner     2           4.9
# ...          ...   ...     ...    ...   ...     ...   ...           ...
# 6900       28.17  6.50  Female    Yes   Sat  Dinner     3           5.9
# 6901       15.98  3.00  Female     No   Fri   Lunch     3           5.9
# 6902       15.69  3.00    Male    Yes   Sat  Dinner     3           5.9
# 6903       35.83  4.67  Female     No   Sat  Dinner     3           5.9
# 6904       29.03  5.92    Male     No   Sat  Dinner     3           5.9
#
#       sepal_width  petal_length  petal_width    species
# ...

# %%
d1=df1[1:6]
# d1=df1.sample(5)
d1
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4

# %%
# d2 = df2.sample(5)
d2=df2[1:6]
d2
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  size
# 1           4.9          3.0           1.4          0.2  setosa     2
# 2           4.7          3.2           1.3          0.2  setosa     2
# 3           4.6          3.1           1.5          0.2  setosa     2
# 4           5.0          3.6           1.4          0.2  setosa     1
# 5           5.4          3.9           1.7          0.4  setosa     1

# %%
pd.concat([d1, d2], axis=0)
# Out:
#    total_bill   tip     sex smoker  day    time  size  sepal_length  \
# 1       10.34  1.66    Male     No  Sun  Dinner     3           NaN
# 2       21.01  3.50    Male     No  Sun  Dinner     3           NaN
# 3       23.68  3.31    Male     No  Sun  Dinner     2           NaN
# 4       24.59  3.61  Female     No  Sun  Dinner     4           NaN
# 5       25.29  4.71    Male     No  Sun  Dinner     4           NaN
# 1         NaN   NaN     NaN    NaN  NaN     NaN     2           4.9
# 2         NaN   NaN     NaN    NaN  NaN     NaN     2           4.7
# 3         NaN   NaN     NaN    NaN  NaN     NaN     2           4.6
# 4         NaN   NaN     NaN    NaN  NaN     NaN     1           5.0
# 5         NaN   NaN     NaN    NaN  NaN     NaN     1           5.4
#
#    sepal_width  petal_length  petal_width species
# 1          NaN           NaN          NaN     NaN
# 2          NaN           NaN          NaN     NaN
# 3          NaN           NaN          NaN     NaN
# ...

# %%
df3 = pd.merge(d1, d2, how='left', on='size')

df3
# Out:
#    total_bill   tip     sex smoker  day    time  size  sepal_length  \
# 0       10.34  1.66    Male     No  Sun  Dinner     3           NaN
# 1       21.01  3.50    Male     No  Sun  Dinner     3           NaN
# 2       23.68  3.31    Male     No  Sun  Dinner     2           4.9
# 3       23.68  3.31    Male     No  Sun  Dinner     2           4.7
# 4       23.68  3.31    Male     No  Sun  Dinner     2           4.6
# 5       24.59  3.61  Female     No  Sun  Dinner     4           NaN
# 6       25.29  4.71    Male     No  Sun  Dinner     4           NaN
#
#    sepal_width  petal_length  petal_width species
# 0          NaN           NaN          NaN     NaN
# 1          NaN           NaN          NaN     NaN
# 2          3.0           1.4          0.2  setosa
# 3          3.2           1.3          0.2  setosa
# 4          3.1           1.5          0.2  setosa
# 5          NaN           NaN          NaN     NaN
# 6          NaN           NaN          NaN     NaN

# %%
df3 = pd.merge(d1, d2, how='right', on='size')
df3
# Out:
#    total_bill   tip   sex smoker  day    time  size  sepal_length  \
# 0       23.68  3.31  Male     No  Sun  Dinner     2           4.9
# 1       23.68  3.31  Male     No  Sun  Dinner     2           4.7
# 2       23.68  3.31  Male     No  Sun  Dinner     2           4.6
# 3         NaN   NaN   NaN    NaN  NaN     NaN     1           5.0
# 4         NaN   NaN   NaN    NaN  NaN     NaN     1           5.4
#
#    sepal_width  petal_length  petal_width species
# 0          3.0           1.4          0.2  setosa
# 1          3.2           1.3          0.2  setosa
# 2          3.1           1.5          0.2  setosa
# 3          3.6           1.4          0.2  setosa
# 4          3.9           1.7          0.4  setosa

# %%
df3 = pd.merge(d1, d2, how='outer', on='size')
df3
# Out:
#    total_bill   tip     sex smoker  day    time  size  sepal_length  \
# 0       10.34  1.66    Male     No  Sun  Dinner     3           NaN
# 1       21.01  3.50    Male     No  Sun  Dinner     3           NaN
# 2       23.68  3.31    Male     No  Sun  Dinner     2           4.9
# 3       23.68  3.31    Male     No  Sun  Dinner     2           4.7
# 4       23.68  3.31    Male     No  Sun  Dinner     2           4.6
# 5       24.59  3.61  Female     No  Sun  Dinner     4           NaN
# 6       25.29  4.71    Male     No  Sun  Dinner     4           NaN
# 7         NaN   NaN     NaN    NaN  NaN     NaN     1           5.0
# 8         NaN   NaN     NaN    NaN  NaN     NaN     1           5.4
#
#    sepal_width  petal_length  petal_width species
# 0          NaN           NaN          NaN     NaN
# 1          NaN           NaN          NaN     NaN
# 2          3.0           1.4          0.2  setosa
# 3          3.2           1.3          0.2  setosa
# ...

# %%
df3 = pd.merge(d1, d2, how='inner', on='size')

df3
# Out:
#    total_bill   tip   sex smoker  day    time  size  sepal_length  \
# 0       23.68  3.31  Male     No  Sun  Dinner     2           4.9
# 1       23.68  3.31  Male     No  Sun  Dinner     2           4.7
# 2       23.68  3.31  Male     No  Sun  Dinner     2           4.6
#
#    sepal_width  petal_length  petal_width species
# 0          3.0           1.4          0.2  setosa
# 1          3.2           1.3          0.2  setosa
# 2          3.1           1.5          0.2  setosa
